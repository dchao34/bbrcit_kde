# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from kde_visual_utils import plot_contour2d, plot_data2d
import re

# %%
fig = plt.figure(figsize=(24,36))

ax = fig.add_subplot(3,2,1)
plot_data2d('test_kde13_data.csv', ax=ax, title=r'input sample', xlim=[-2,2], ylim=[-2,2])
ax = fig.add_subplot(3,2,3)
plot_contour2d('test_kde13_cpu_direct.csv', ax=ax, title=r'cpu direct', nlevels=10, colorbar=False)
ax = fig.add_subplot(3,2,4)
plot_contour2d('test_kde13_cpu_tree.csv', ax=ax, title=r'cpu tree', nlevels=10, colorbar=False)
ax = fig.add_subplot(3,2,5)
plot_contour2d('test_kde13_gpu_direct.csv', ax=ax, title=r'gpu direct', nlevels=10, colorbar=False)
ax = fig.add_subplot(3,2,6)
plot_contour2d('test_kde13_gpu_tree.csv', ax=ax, title=r'gpu tree', nlevels=10, colorbar=False)
