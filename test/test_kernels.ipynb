# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
arr = np.genfromtxt('test_epanechnikov1d.csv')
fig = plt.figure(figsize=(5*1.618, 5))
ax = fig.add_subplot(1,1,1)
ax.plot(arr[:,0], arr[:,1]);
