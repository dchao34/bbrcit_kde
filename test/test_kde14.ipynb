# %%
import numpy as np
import matplotlib.pyplot as plt
from kde_visual_utils import plot_data1d
# %matplotlib inline

# %%
fig = plt.figure(figsize=(7*1.618, 7))

ax = fig.add_subplot(2,2,1)
plot_data1d('test_kde14_cpu_direct.csv', ax, title='cpu direct')
ax = fig.add_subplot(2,2,2)
plot_data1d('test_kde14_cpu_tree.csv', ax, title='cpu dual tree')
ax = fig.add_subplot(2,2,3)
plot_data1d('test_kde14_gpu_direct.csv', ax, title='gpu direct')
ax = fig.add_subplot(2,2,4)
plot_data1d('test_kde14_gpu_tree.csv', ax, title='gpu dual tree')
plt.tight_layout()
