# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from kde_visual_utils import plot_contour2d, plot_data2d
import re

# %%
fig = plt.figure(figsize=(24,24))

ax = fig.add_subplot(2,2,1)
plot_data2d('test_kde4_data.csv', ax=ax, title=r'input sample', xlim=[-2,2], ylim=[-2,2])
ax = fig.add_subplot(2,2,2)
plot_contour2d('test_kde4_naive.csv', ax=ax, title=r'naive', nlevels=5, colorbar=False)
ax = fig.add_subplot(2,2,3)
plot_contour2d('test_kde4_single.csv', ax=ax, title=r'single tree', nlevels=5, colorbar=False)
ax = fig.add_subplot(2,2,4)
plot_contour2d('test_kde4_dual.csv', ax=ax, title=r'dual tree', nlevels=5, colorbar=False)

# %%
fig = plt.figure(figsize=(32,12))
ax = fig.add_subplot(1,2,1)
plot_contour2d('test_kde4_single.csv', ax=ax, title=r'single tree', nlevels=5)
ax = fig.add_subplot(1,2,2)
plot_contour2d('test_kde4_dual.csv', ax=ax, title=r'dual tree', nlevels=5)
